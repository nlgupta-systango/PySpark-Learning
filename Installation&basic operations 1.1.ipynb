# %%
pip install pyspark
# Out:
# ...
#      ---------------------------------------- 0.0/310.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/310.8 MB ? eta -:--:--
#      -------------------------------------- 0.0/310.8 MB 435.7 kB/s eta 0:11:54
#      -------------------------------------- 0.0/310.8 MB 245.8 kB/s eta 0:21:05
#      -------------------------------------- 0.0/310.8 MB 245.8 kB/s eta 0:21:05
#      -------------------------------------- 0.1/310.8 MB 272.3 kB/s eta 0:19:01
#      -------------------------------------- 0.1/310.8 MB 385.0 kB/s eta 0:13:28
#      -------------------------------------- 0.1/310.8 MB 448.2 kB/s eta 0:11:34
#      -------------------------------------- 0.1/310.8 MB 448.2 kB/s eta 0:11:34
#      -------------------------------------- 0.2/310.8 MB 471.4 kB/s eta 0:10:59
#      -------------------------------------- 0.2/310.8 MB 533.8 kB/s eta 0:09:42
#      -------------------------------------- 0.3/310.8 MB 528.9 kB/s eta 0:09:48
# ...

# %%
print("Working")
# Out:
# Working

# %%
# !pip install pyspark

# %%
import pandas as pd

# %%
pd_df = pd.read_csv('CSV sample/task.csv')

# %%
pd_df
# Out:
#       Project                                              Tasks  \
# 0         NaN                                                NaN
# 1     January                                                NaN
# 2    Power BI                                BRM update for 2023
# 3    Power BI  BRM updating query to include prev year data a...
# 4    Power BI                  BRM issue with comparision report
# ..        ...                                                ...
# 273  Power BI  Review all kelley kronenberg report to add PAM...
# 274  Power BI  Added PAM and EKH unit as RLS into Client Fina...
# 275  Power BI  Tested the Added RLS for Client Financials - M...
# 276  Power BI                                                NaN
# 277  Power BI                                                NaN
#
#            Responsible  Hours      Month
# 0                  NaN    NaN        NaN
# 1                  NaN    NaN        NaN
# 2    Surbhi Khandelwal    5.0    January
# ...

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('SparkLearning').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-PFU6LNS:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>SparkLearning</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-PFU6LNS:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>SparkLearning</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_of_spark = spark.read.csv('CSV sample/task.csv')

# %%
df_of_spark
# Out:
# DataFrame[_c0: string, _c1: string, _c2: string, _c3: string, _c4: string]

# %%
df_of_spark.show()
# Out:
# +--------------------+--------------------+-----------------+-----+-------+
# |                 _c0|                 _c1|              _c2|  _c3|    _c4|
# +--------------------+--------------------+-----------------+-----+-------+
# |             Project|               Tasks|      Responsible|Hours|  Month|
# |                null|                null|             null| null|   null|
# |             January|                null|             null| null|   null|
# |            Power BI| BRM update for 2023|Surbhi Khandelwal|    5|January|
# |            Power BI|BRM updating quer...|             null| null|   null|
# |,Surbhi Khandelwa...|                null|             null| null|   null|
# |            Power BI|BRM issue with co...|Surbhi Khandelwal|    7|January|
# |            Power BI|BRM issue with Ra...|Surbhi Khandelwal|    4|January|
# |            Power BI|Research on how t...|Surbhi Khandelwal|    4|January|
# ...

# %%
df_of_spark.head(10)
# Out:
# [Row(_c0='Project', _c1='Tasks', _c2='Responsible', _c3='Hours', _c4='Month'),
#  Row(_c0=None, _c1=None, _c2=None, _c3=None, _c4=None),
#  Row(_c0='January', _c1=None, _c2=None, _c3=None, _c4=None),
#  Row(_c0='Power BI', _c1='BRM update for 2023', _c2='Surbhi Khandelwal', _c3='5', _c4='January'),
#  Row(_c0='Power BI', _c1='BRM updating query to include prev year data along with adding year column', _c2=None, _c3=None, _c4=None),
#  Row(_c0=',Surbhi Khandelwal,7,January', _c1=None, _c2=None, _c3=None, _c4=None),
#  Row(_c0='Power BI', _c1='BRM issue with comparision report', _c2='Surbhi Khandelwal', _c3='7', _c4='January'),
#  Row(_c0='Power BI', _c1='BRM issue with Rates report', _c2='Surbhi Khandelwal', _c3='4', _c4='January'),
#  Row(_c0='Power BI', _c1='Research on how to integrate power bi reports into dynamics 365', _c2='Surbhi Khandelwal', _c3='4', _c4='January'),
#  Row(_c0='Power BI', _c1='BRM add departments', _c2='Surbhi Khandelwal', _c3='3', _c4='January')]

# %%
df_of_spark.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)

# %%
# Get Existing SparkSession
spark3 = SparkSession.builder.getOrCreate
print(spark3)
# Out:
# <bound method SparkSession.Builder.getOrCreate of <pyspark.sql.session.SparkSession.Builder object at 0x00000240A26DD390>>
